# %% [markdown]
# # Pandas Tutorial

# %% [markdown]
# Pandas ist ein Python Paket welches performante und benutzerfreundliche Datenstrukturen sowie Datenanalysetools bereitstellt.
#
# Pandas stellt mit *Series* und *Dataframe* zwei zentrale Datenstrukturen bereit, die im folgenden genauer beschrieben werden.
#
# Das Pandas Paket muss über `pip` installiert werden und kann dann wie folgt importiert werden, wobei es üblich ist das Paket unter dem Namen `pd` zu importieren.

# %%
import pandas as pd

# %% [markdown]
# ## Series
#
# Series ist ein eindimensionales beschriftetes Array , welches jeden Datentyp (Ganzzahlen, Zeichenfolgen, Gleitkommazahlen, Python-Objekte usw.) enthalten kann. Die Achsenbeschriftungen werden zusammen als Index bezeichnet. Eine Series kann wie folgt erstellt werden:

# %%
pd.Series(["Dortmund", "Schalke", "Köln", "Frankfurt", "München"], index=["a", "b", "c", "d", "e"])
# Out:
# a     Dortmund
# b      Schalke
# c         Köln
# d    Frankfurt
# e      München
# dtype: object

# %% [markdown]
# Auf Elemente innerhalb einer Series kann über die Position (die erste Position ist 0!) sowie den Index zugegriffen werden.

# %%
series = pd.Series(["Dortmund", "Schalke", "Köln", "Frankfurt", "München"], index=["a", "b", "c", "d", "e"])
print(f"Element an Position 0: {series[0]}")
print(f"Element unter Index c: {series['c']}")
# Out:
# Element an Position 0: Dortmund
# Element unter Index c: Köln

# %%
Eine Series kann auch in Teile zerlegt werden sowie Funktionen zum zerlegen genutzt werden

# %%
series = pd.Series(["Dortmund", "Schalke", "Köln", "Frankfurt", "München"], index=["a", "b", "c", "d", "e"])

# %%
## Dataframe

# %%
import requests
import json
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-8acd0fd1b8c1> in <module>
#       1 import requests
#       2 import json
# ----> 3 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
antwort = requests.get('https://www.openligadb.de/api/getbltable/bl1/2020')

# %%
pd.DataFrame(antwort.json())
# Out:
#     TeamInfoId                  TeamName     ShortName  \
# 0           40         FC Bayern München        Bayern
# 1         1635                RB Leipzig       Leipzig
# 2            6          Bayer Leverkusen    Leverkusen
# 3          131             VfL Wolfsburg     Wolfsburg
# 4           87  Borussia Mönchengladbach      Gladbach
# 5           91       Eintracht Frankfurt     Frankfurt
# 6            7   BV Borussia Dortmund 09      Dortmund
# 7           80        1. FC Union Berlin  Union Berlin
# 8          112               SC Freiburg      Freiburg
# 9           16             VfB Stuttgart     Stuttgart
# 10         175       TSG 1899 Hoffenheim    Hoffenheim
# 11          95               FC Augsburg      Augsburg
# 12         134             Werder Bremen        Bremen
# 13          54                Hertha BSC        Hertha
# 14          83         Arminia Bielefeld     Bielefeld
# 15          65                1. FC Köln          Köln
# ...
