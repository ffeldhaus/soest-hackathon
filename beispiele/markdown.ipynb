# %% [markdown]
# # Hallo Welt!
#
# Dies ist ein **Markdown** Beispiel mit einem [Link auf das Markdown Tutorial](https://drdanielappel.de/tipps-tools/markdown-eine-einfach-zu-erlernende-auszeichnungssprache/) sowie einer Graphik zur *Stadt Soest*:
# !["Bronzeskulptur der Stadt Soest"](https://upload.wikimedia.org/wikipedia/commons/6/6c/Soest-IMG_0765.JPG)
